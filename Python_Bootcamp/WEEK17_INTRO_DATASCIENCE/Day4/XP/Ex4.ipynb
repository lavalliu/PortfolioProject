# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]  # Prices
y = [5, 4, 3, 2, 1]  # Demand

fig,ax=plt.subplots()
ax.set_title('Product Demand vs Price')
ax.plot(x,y)
ax.set_xlabel('Price')
ax.set_ylabel('Demand')
# Out:
# Text(0, 0.5, 'Demand')
