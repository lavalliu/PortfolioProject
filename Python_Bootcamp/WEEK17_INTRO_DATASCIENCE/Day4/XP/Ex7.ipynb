# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 1000)
y1 = np.sin(x)
y2 = np.cos(x)

fig,ax=plt.subplots()
ax.set_title('y = sin(x)')
ax.plot(x,y1)

fig,ax=plt.subplots()
ax.set_title('y = cos(x)')
ax.scatter(x,y2 , color='tab:green')
